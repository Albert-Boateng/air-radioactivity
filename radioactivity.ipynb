# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://drive.google.com/file/d/1RLgBVWXvQxmcm63w9Cg7FRJJZouhw4x-/view'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df
# Out:
#        Location Province  Collection Year  Collection Month  Collection Day  \
# 0         Alert       NU             2009                 1               5
# 1         Alert       NU             2009                 1              12
# 2         Alert       NU             2009                 1              19
# 3         Alert       NU             2009                 1              26
# 4         Alert       NU             2009                 2               2
# ...         ...      ...              ...               ...             ...
# 25831  Winnipeg       MB             2022                 2               8
# 25832  Winnipeg       MB             2022                 2              15
# 25833  Winnipeg       MB             2022                 2              22
# 25834  Winnipeg       MB             2022                 3              21
# 25835  Winnipeg       MB             2022                 4               5
#
#        Collection Time (s)  Air Volume (m3)  7Be Activity (mBq/m3)  \
# 0                   605280       1852.00000               2.775336
# 1                   602040       1838.00000               2.511766
# 2                   594900       1952.00000               2.623490
# 3                   606180       2108.00000               1.531583
# 4                   605220       2030.00000               3.542633
# ...                    ...              ...                    ...
# 25831               608160      12627.79980               2.504462
# 25832               600480      12463.29980               2.882208
# 25833               605220      12568.00000               2.397653
# 25834              1286580      26409.90039               1.948618
# 25835               605940      12439.90039               2.665944
#
#        7Be Uncertainty (mBq/m3)  7Be MDC (mBq/m3)  ...  134Cs MDC (mBq/m3)  \
# 0                      0.119936          0.183023  ...            0.017734
# 1                      0.112781          0.186647  ...            0.015256
# 2                      0.125648          0.215237  ...            0.014541
# 3                      0.087783          0.182367  ...            0.014751
# 4                      0.137878          0.182481  ...            0.015939
# ...                         ...               ...  ...                 ...
# 25831                  0.081238          0.054321  ...            0.005647
# 25832                  0.088488          0.044860  ...            0.004136
# 25833                  0.074691          0.038768  ...            0.003922
# 25834                  0.055365          0.018533  ...            0.001683
# 25835                  0.081997          0.042262  ...            0.003757
#
#        137Cs Activity (mBq/m3)  137Cs Uncertainty (mBq/m3)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 25831                      NaN                         NaN
# 25832                      NaN                         NaN
# 25833                      NaN                         NaN
# 25834                      NaN                         NaN
# 25835                      NaN                         NaN
#
#        137Cs MDC (mBq/m3)  131I Activity (mBq/m3)  131I Uncertainty (mBq/m3)  \
# 0                0.014081                     NaN                        NaN
# 1                0.014959                     NaN                        NaN
# 2                0.013357                     NaN                        NaN
# 3                0.012981                     NaN                        NaN
# 4                0.013104                     NaN                        NaN
# ...                   ...                     ...                        ...
# 25831            0.004030                     NaN                        NaN
# 25832            0.003545                     NaN                        NaN
# 25833            0.003345                     NaN                        NaN
# 25834            0.001526                     NaN                        NaN
# 25835            0.003022                     NaN                        NaN
#
#        131I MDC (mBq/m3)  106Ru Activity (mBq/m3)  106Ru Uncertainty (mBq/m3)  \
# 0               1.402004                      NaN                         NaN
# 1               1.572990                      NaN                         NaN
# 2               7.825901                      NaN                         NaN
# 3               3.896823                      NaN                         NaN
# 4               2.436548                      NaN                         NaN
# ...                  ...                      ...                         ...
# 25831           0.122039                      NaN                         NaN
# 25832           0.208764                      NaN                         NaN
# 25833           0.129917                      NaN                         NaN
# 25834           0.044475                      NaN                         NaN
# 25835           0.153374                      NaN                         NaN
#
#        106Ru MDC (mBq/m3)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 25831                 NaN
# 25832                 NaN
# 25833                 NaN
# 25834                 NaN
# 25835                 NaN
#
# [25836 rows x 25 columns]

# %%
df['Location'].unique()
# Out:
# array(['Alert', 'Amherstburg', 'Calgary', 'Charlottetown', 'Churchill',
#        'Coral Harbour', 'Digby', 'Edmonton', 'Goose Bay', 'Greenwood',
#        'Halifax', 'Inuvik', 'Iqaluit', 'Kuujjuarapik', 'Moncton',
#        'Montreal', 'Moosonee', 'Ottawa', 'Port Hope', 'Quebec City',
#        'Regina', 'Resolute', 'RPB', 'Saskatoon', 'Sidney', 'St. Johns',
#        'Toronto', 'Vancouver', 'Whitehorse', 'Winnipeg'], dtype=object)

# %%
dic={'Alert': 62, 'Amherstburg':21936, 'Calgary': 1481806, 'Charlottetown': 36094,
     'Churchill':899,'Coral Harbour': 891, 'Digby':2092,'Edmonton': 1519000,
     'Goose Bay':8151, 'Greenwood': 695,'Halifax': 417000, 'Inuvik': 3400,
     'Iqaluit':7740,'Kuujjuarapik':792, 'Moncton':75401,'Montreal':4277000,
     'Moosonee':1569, 'Ottawa': 1423000,'Port Hope':17294, 'Quebec City':838000,
     'Regina':219786, 'Resolute':183, 'RPB':39607, 'Saskatoon': 337000, 'Sidney': 11583,
     'St. Johns':178427,'Toronto':6313000,'Vancouver':2632000, 'Whitehorse':28201, 'Winnipeg':833000}
dic1=sorted(dic.items(),key=lambda x:x[1])[::-1]
lis=[]
for i in dic1:
  lis+=[i[0]]

# %%
import warnings
warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages
for j in range(7,len(df.columns)-3,3):
  k=df.columns[j].split()[0]
  for i in df['Location'].unique():
    variable = df.columns[j]
    dfy=df[df['Location']==f'{i}']

    plt.subplot(2, 1, 1)
    sns.boxplot(x=dfy['Collection Year'], y=dfy[variable])
    plt.title(f'{i}', fontsize = 10, loc='center', fontdict=dict(weight='bold'))
    plt.xlabel('Year', fontsize = 10, fontdict=dict(weight='bold'))
    plt.ylabel(f'{variable}'[:-8], fontsize = 10, fontdict=dict(weight='bold'))

    plt.subplot(2, 1, 2)
    sns.boxplot(x=dfy['Collection Month'], y=dfy[variable])
    plt.xlabel('Month', fontsize = 10, fontdict=dict(weight='bold'))
    plt.ylabel(f'', fontsize = 10, fontdict=dict(weight='bold'))

    #plt.savefig(f'{i}{j}.png')
    plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
from matplotlib.backends.backend_pdf import PdfPages
for j in range(7,len(df.columns)-3,3):
  k=df.columns[j].split()[0]
  with PdfPages(f'{k}.pdf') as export_pdf:
    for i in df['Location'].unique():
      variable = df.columns[j]
      dfy=df[df['Location']==f'{i}']
      fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

      sns.boxplot(x=dfy['Collection Year'], y=dfy[variable], ax=ax[0])
      ax[0].set_title(f'Year-wise Box Plot\n({i})', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
      ax[0].set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
      ax[0].set_ylabel(f'{variable}', fontsize = 16, fontdict=dict(weight='bold'))

      sns.boxplot(x=dfy['Collection Month'], y=dfy[variable], ax=ax[1])
      ax[1].set_title(f'Month-wise Box Plot\n({i})', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
      ax[1].set_xlabel('Month', fontsize = 16, fontdict=dict(weight='bold'))
      ax[1].set_ylabel(f'{variable}', fontsize = 16, fontdict=dict(weight='bold'))
      plt.savefig(f'{i}{j}.png')
      plt.show()

# %%
col1=list(df.columns[3:7])
col2=list(df.columns[-3:-1])
data=df.drop(col1,axis=1).drop(col2,axis=1).drop(['Province','106Ru MDC (mBq/m3)'],axis=1)
town=[]
for i in data.Location.unique():
    i=data[data.Location==i]
    town+=[i]
years=town[0]['Collection Year'].unique()
location=data.Location.unique()
cols=data.columns[2:]

# %%
df_mean=pd.DataFrame(columns=data.columns)
for i in range(len(town)):
  u=town[i]
  for j in u['Collection Year'].unique():
    dy=[u.iloc[1,0],j]
    for k in cols:
      c=u[u['Collection Year']==j][k].mean()
      dy+=[c]
    df_mean.loc[len(df_mean)]=dy
#df_mean
df_std=pd.DataFrame(columns=data.columns)
for i in range(len(town)):
  u=town[i]
  for j in u['Collection Year'].unique():
    dy=[u.iloc[1,0],j]
    for k in cols:
      c=u[u['Collection Year']==j][k].std()
      dy+=[c]
    df_std.loc[len(df_std)]=dy
#df_std
df_max=pd.DataFrame(columns=data.columns)
for i in range(len(town)):
  u=town[i]
  for j in u['Collection Year'].unique():
    dy=[u.iloc[1,0],j]
    for k in cols:
      c=u[u['Collection Year']==j][k].max()
      dy+=[c]
    df_max.loc[len(df_max)]=dy
#df_max

# %%
df_mean.columns
# Out:
# Index(['Location', 'Collection Year', '7Be Activity (mBq/m3)',
#        '7Be Uncertainty (mBq/m3)', '7Be MDC (mBq/m3)',
#        '210Pb Activity (mBq/m3)', '210Pb Uncertainty (mBq/m3)',
#        '210Pb MDC (mBq/m3)', '134Cs Activity (mBq/m3)',
#        '134Cs Uncertainty (mBq/m3)', '134Cs MDC (mBq/m3)',
#        '137Cs Activity (mBq/m3)', '137Cs Uncertainty (mBq/m3)',
#        '137Cs MDC (mBq/m3)', '131I Activity (mBq/m3)',
#        '131I Uncertainty (mBq/m3)', '131I MDC (mBq/m3)'],
#       dtype='object')

# %%
for i in df_mean['Location'].unique():
  dv=df_mean[df_mean['Location']==i]
  x=dv['Collection Year']
  for j in range(2,len(df_mean.columns),3):
    y=dv.iloc[:,[j]]
    plt.scatter(x,y)
    plt.plot(x,y, label=df_mean.columns[j])
    plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1))
  plt.title(i)
  plt.show()

# %%
df_mean
# Out:
#      Location Collection Year  7Be Activity (mBq/m3)  \
# 0       Alert            2009               2.539149
# 1       Alert            2010               2.888491
# 2       Alert            2011               2.293081
# 3       Alert            2012               2.153352
# 4       Alert            2013               1.987351
# ..        ...             ...                    ...
# 370  Winnipeg            2018               3.058100
# 371  Winnipeg            2019               2.981359
# 372  Winnipeg            2020               3.068844
# 373  Winnipeg            2021               3.064543
# 374  Winnipeg            2022               2.476111
#
#      7Be Uncertainty (mBq/m3)  7Be MDC (mBq/m3)  210Pb Activity (mBq/m3)  \
# 0                    0.119505          0.236398                 0.444610
# 1                    0.243718          1.010645                 0.387877
# 2                    0.121643          0.411170                 0.460854
# 3                    0.145062          0.430048                 0.449906
# 4                    0.143419          0.414148                 0.529190
# ..                        ...               ...                      ...
# 370                  0.085676          0.037155                 0.537517
# 371                  0.083187          0.037572                 0.430231
# 372                  0.088415          0.044999                 0.481737
# 373                  0.084357          0.038484                 0.586044
# 374                  0.076301          0.039069                 0.864413
#
#      210Pb Uncertainty (mBq/m3)  210Pb MDC (mBq/m3)  134Cs Activity (mBq/m3)  \
# 0                      0.030309            0.083984                      NaN
# 1                      0.028398            0.086854                      NaN
# 2                      0.029960            0.101040                 0.229211
# 3                      0.032289            0.109076                      NaN
# 4                      0.033532            0.094083                      NaN
# ..                          ...                 ...                      ...
# 370                    0.025161            0.040026                      NaN
# 371                    0.020884            0.037188                      NaN
# 372                    0.022172            0.032521                      NaN
# 373                    0.026373            0.038485                      NaN
# 374                    0.033976            0.029248                      NaN
#
#      134Cs Uncertainty (mBq/m3)  134Cs MDC (mBq/m3)  137Cs Activity (mBq/m3)  \
# 0                           NaN            0.016633                      NaN
# 1                           NaN            0.017979                      NaN
# 2                      0.004064            0.018665                 0.181205
# 3                           NaN            0.020655                      NaN
# 4                           NaN            0.017288                      NaN
# ..                          ...                 ...                      ...
# 370                         NaN            0.005328                      NaN
# 371                         NaN            0.005130                 0.001026
# 372                         NaN            0.004595                      NaN
# 373                         NaN            0.005115                      NaN
# 374                         NaN            0.003797                      NaN
#
#      137Cs Uncertainty (mBq/m3)  137Cs MDC (mBq/m3)  131I Activity (mBq/m3)  \
# 0                           NaN            0.013913                     NaN
# 1                           NaN            0.013458                     NaN
# 2                      0.004373            0.011530                  2.0994
# 3                           NaN            0.013586                     NaN
# 4                           NaN            0.013088                     NaN
# ..                          ...                 ...                     ...
# 370                         NaN            0.003998                     NaN
# 371                    0.000385            0.003854                     NaN
# 372                         NaN            0.003513                     NaN
# 373                         NaN            0.003674                     NaN
# 374                         NaN            0.003193                     NaN
#
#      131I Uncertainty (mBq/m3)  131I MDC (mBq/m3)
# 0                          NaN       6.799757e+01
# 1                          NaN       2.343014e+06
# 2                     0.032762       4.490770e+10
# 3                          NaN       1.644919e+03
# 4                          NaN       5.459551e+03
# ..                         ...                ...
# 370                        NaN       2.729924e-02
# 371                        NaN       3.173355e-02
# 372                        NaN       4.338877e-01
# 373                        NaN       9.907524e-02
# 374                        NaN       1.092804e-01
#
# [375 rows x 17 columns]

# %%
df_mean['Location'].unique()
# Out:
# array(['Alert', 'Amherstburg', 'Calgary', 'Charlottetown', 'Churchill',
#        'Coral Harbour', 'Digby', 'Edmonton', 'Goose Bay', 'Greenwood',
#        'Halifax', 'Inuvik', 'Iqaluit', 'Kuujjuarapik', 'Moncton',
#        'Montreal', 'Moosonee', 'Ottawa', 'Port Hope', 'Quebec City',
#        'Regina', 'Resolute', 'RPB', 'Saskatoon', 'Sidney', 'St. Johns',
#        'Toronto', 'Vancouver', 'Whitehorse', 'Winnipeg'], dtype=object)

# %%
df_mean['Location']
# Out:
# 0         Alert
# 1         Alert
# 2         Alert
# 3         Alert
# 4         Alert
#          ...
# 370    Winnipeg
# 371    Winnipeg
# 372    Winnipeg
# 373    Winnipeg
# 374    Winnipeg
# Name: Location, Length: 375, dtype: object

# %%
for i in df_mean.columns[2::3]:
  for j in df_mean['Location'].unique():
    x=df_mean['Collection Year'][df_mean['Location']==j]
    y=df_mean[i][df_mean['Location']==j]
    plt.scatter(x,y)
    plt.plot(x,y, label=j)
    plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1))
  plt.title(i)
  plt.show()

# %%
for j in range(7,len(df.columns)-3,3):
  k=df.columns[j].split()[0]
  for i in df['Location'].unique():
    variable = df.columns[j]
    dfy=df[df['Location']==f'{i}']
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

    sns.boxplot(dfy['Collection Year'], dfy[variable], ax=ax[0])
    ax[0].set_title(f'Year-wise Box Plot\n({i})', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
    ax[0].set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
    ax[0].set_ylabel(f'{variable}', fontsize = 16, fontdict=dict(weight='bold'))

    sns.boxplot(dfy['Collection Month'], dfy[variable], ax=ax[1])
    ax[1].set_title(f'Month-wise Box Plot\n({i})', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
    ax[1].set_xlabel('Month', fontsize = 16, fontdict=dict(weight='bold'))
    ax[1].set_ylabel(f'{variable}', fontsize = 16, fontdict=dict(weight='bold'))
    #plt.savefig(f'{i}{j}.png')
    plt.show()
